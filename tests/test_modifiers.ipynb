# %%
from pmrf.statistics.modifiers import Modifier
from pmrf import numpy as np

# %%
mod = Modifier('multiply-every-2')
x = np.array([4.0, 2.0, 2.0, 3.0])
mod(x)
# Out:
# Array([[8., 6.]], dtype=float64)
